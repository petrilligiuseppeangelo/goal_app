# %% [markdown]
# <a href="https://colab.research.google.com/github/petrilligiuseppeangelo/goal_app/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 2. Installa pacchetti
# !pip install pandas numpy matplotlib

# %%
# 3. Importa librerie
import pandas as pd
import matplotlib.pyplot as plt

# %%
# 4. Carica dati
df = pd.read_csv('/content/drive/MyDrive/dati.csv')

# %%
# 5. Analisi
print(df.head())
df.describe()

# %%
# 1. Collega Google Drive
from google.colab import drive
drive.mount('/content/drive')

# %%
# 6. Visualizzazione
plt.figure(figsize=(10,6))
plt.plot(df['data'], df['valore'])
plt.title('Miei Dati')
plt.show()
